# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Load job market
df = pd.read_csv('job-market(2).csv')
df.head(3)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
#
#                Company                      Date               Location  \
# 0          Aldi Stores  2018-10-07T00:00:00.000Z                 Sydney
# 1          Aldi Stores  2018-10-07T00:00:00.000Z  Richmond & Hawkesbury
# 2  LB Creative Pty Ltd  2018-10-07T00:00:00.000Z               Brisbane
#
#                           Area              Classification  SubClassification  \
# 0  North West & Hills District  Retail & Consumer Products  Retail Assistants
# 1                          NaN  Retail & Consumer Products  Retail Assistants
# 2          CBD & Inner Suburbs  Retail & Consumer Products  Retail Assistants
#
#                                          Requirement FullDescription  \
# ...

# %%
# %matplotlib inline

y_ = df.iloc[:,0]
data = df.dropna()
y = data.iloc[:,0]
  #y.shape[0]
  #len(df.index) #40789
  #df[df.columns[0]].count() #10099
  #non_NaN = df[~np.isnan(df)]

  #non_NaN = df.dropna()
  #non_NaN.count()

  #df[df.columns[0]].count()

#y.isnull().sum() # 30690
#y2 = y.dropna()
#y2.isnull().sum() # 0

#df.isnull().count() # 40789
#df.count() #10099

#y_classification = data.iloc[:,6]
#y_classification.count() #5898
#y_classification_u = y_classification.unique()
#y_classification_u
#x_NoOfPostings = y_classification_u[0].value_counts()

jobNums = df['Classification'].value_counts()
#jobNums.plot(kind='bar')
#plt.plot(jobNums)

#type(jobNums)
#jobNums
#plt.plot(jobNums.index, jobNums.values)

## Adapted
## https://matplotlib.org/stable/gallery/lines_bars_and_markers/barh.html
##

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
#people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(jobNums.index))
industry = jobNums.values
error = np.random.rand(len(jobNums.index))

ax.barh(y_pos, industry, xerr=error, align='center')
ax.set_yticks(y_pos, labels=jobNums.index)#people
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Number of Postings')
ax.set_ylabel('Classification')
ax.set_title('Jobs and number of postings')

plt.show()

# %%
import matplotlib
#create dataframe for salary ranges

#sample = df.head(5)
#sample
#sample['HighestSalary'].sum() # 150.0
#df[df['HighestSalary']>60]
#LowestSalary
#HighestSalary

#range_1 = df[(df['LowestSalary']<=0) & (df['LowestSalary']<=30)] #(3894/40789) * 100
#range_2 = df[(df['LowestSalary']<=30) & (df['LowestSalary']<=40)] #(5736/40789) * 100
#range_3 = df[(df['LowestSalary']<=40) & (df['LowestSalary']<=50)] #(8255/40789) * 100
#range_4 = df[(df['LowestSalary']<=50) & (df['LowestSalary']<=60)] #(10099/40789) * 100
#range_5 = df[(df['LowestSalary']<=60) & (df['LowestSalary']>=60)]
#df[df.columns[0]].count()

range_1 = df[(df['LowestSalary']==0)] # 3894
range_2 = df[(df['LowestSalary']==30)] # 1842
range_3 = df[(df['LowestSalary']==40)] # 2519
range_4 = df[(df['LowestSalary']==50)] # 1844
#range_4.shape[0]
#range_1.shape[0]+range_2.shape[0]+range_3.shape[0]+range_4.shape[0]

df[df.columns[0]].count()

bySalary = df.groupby('LowestSalary')
salaryStats = bySalary.count()
salaryStats['Count'] = salaryStats['Id']

#type(salaryStats.index)
#salaryStats.index
salaryStats['Count']
# Out:
# LowestSalary
# 0.0     3894
# 30.0    1842
# 40.0    2519
# 50.0    1844
# Name: Count, dtype: int64

# %%
#salary ranges plot



# create data
names = salaryStats.index
size = salaryStats['Count']

 
# Create a circle at the center of the plot
my_circle = plt.Circle( (0,0), 0.7, color='white')

# Give color names
plt.pie(size, labels=names,autopct='%1.2f%%', colors=['#fc927a','#85cbf3','#e0f2ac','#ffe6ab'],wedgeprops = {'linewidth':7,'edgecolor':'white'})
p = plt.gcf()
p.gca().add_artist(my_circle)
p.gca().set_title('Job Posts by Salary Range')
# Show the graph
plt.show()

# Jobs Posted by salary Range

# %%
locationDf = df[df['Location'].isna()==False]
locationDf = locationDf.groupby('Location').count()
locationDf['Location'] = locationDf.index
locationDf['Count'] = locationDf["Id"]
locationDf.head()
# Out:
#                            Id  Title  Company  Date  Area  Classification  \
# Location
# ACT                       238    238      235   238     0             238
# Adelaide                  390    390      356   390     0             390
# Adelaide Hills & Barossa   19     19       18    19     0              19
# Albany & Great Southern    10     10       10    10     0              10
# Albury Area                19     19       18    19     0              19
#
#                           SubClassification  Requirement  FullDescription  \
# Location
# ACT                                     238          238              235
# Adelaide                                390          390              374
# Adelaide Hills & Barossa                 19           19               19
# Albany & Great Southern                  10           10               10
# Albury Area                              19           19               19
#
# ...

# %%
##
##
##  I STUGGLED WITH CREATING AN INDEX NAMED "Others"
##  AND COMBINING ALL ROWS UNDER THAT INDEX
##



# %matplotlib inline
# Pie char for job market share of cities
from matplotlib import cm

locationDf_Sydney = locationDf[locationDf['Location'].str.match('Sydney')]
locationDf_Melbourne = locationDf[locationDf['Location'] == 'Melbourne']
locationDf_Brisbane = locationDf[locationDf['Location'] == 'Brisbane']
locationDf_Perth = locationDf[locationDf['Location'] == 'Perth']
locationDf_Adelaide = locationDf[locationDf['Location'] == 'Adelaide']

#locationDf.shape[0] # 65
#locationDf2.shape[0] # 60

#locationDf2[locationDf2.columns[0]].count()

#locationDf.shape[0]
#locationDf_Sydney.shape[0]

def sortOthers(location):
    if((location != 'Sydney') & (location !='Melbourne') & (location !='Brisbane') & (location !='Perth') & (location != 'Adelaide')):
        return "Others"
    else:
        return location
    
#locationDf2 = locationDf
#locationDf2['Location'].apply(sortOthers)
#locationDf2

# Some data
labels = locationDf['Location']
fracs = locationDf['Count']

# Make figure and axes
fig, axs = plt.subplots()

# A standard pie plot
axs.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)


# Adapt radius and text size for a smaller pie
patches, texts, autotexts = axs[1, 0].pie(fracs, labels=labels,
                                          autopct='%.0f%%',
                                          textprops={'size': 'smaller'},
                                          shadow=True, radius=0.5)

plt.setp(autotexts, size='x-small')


##
##
##  I STUGGLED WITH CREATING AN INDEX NAMED "Others"
##  AND COMBINING ALL ROWS UNDER THAT INDEX
##
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [242], in <cell line: 41>()
#      37 axs.pie(fracs, labels=labels, autopct='%1.1f%%', shadow=True)
#      40 # Adapt radius and text size for a smaller pie
# ---> 41 patches, texts, autotexts = axs[1, 0].pie(fracs, labels=labels,
#      42                                           autopct='%.0f%%',
#      43                                           textprops={'size': 'smaller'},
#      44                                           shadow=True, radius=0.5)
#      46 plt.setp(autotexts, size='x-small')
#
# TypeError: 'AxesSubplot' object is not subscriptable
